# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from google.colab import drive
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE

# %%
# Mounting Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load dataset
heart_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Biomedical Signal Analysis/heart_disease.csv')

# %%
heart_data.size
heart_data.shape
# Out:
# (919, 14)

# %%
# Display initial data info to understand structure
print("Dataset Info:")
print(heart_data.info())
print("\nSample Data:")
heart_data.head()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 919 entries, 0 to 918
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           919 non-null    int64
#  1   sex           913 non-null    float64
#  2   cp            918 non-null    float64
#  3   trestbps      919 non-null    float64
#  4   chol          919 non-null    float64
#  5   fbs           913 non-null    float64
#  6   restecg       914 non-null    float64
#  7   thalch        919 non-null    float64
#  8   exang         915 non-null    float64
#  9   oldpeak       919 non-null    float64
#  10  slope         917 non-null    float64
#  11  ca            915 non-null    float64
#  12  thal          919 non-null    int64
#  13  heart_status  915 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 100.6 KB
# None
#
# Sample Data:
#    age  sex   cp  trestbps   chol  fbs  restecg  thalch  exang  oldpeak  \
# 0   63  0.0  0.0     145.0  233.0  1.0      2.0   150.0    NaN      2.3
# 1   67  0.0  3.0     160.0  286.0  0.0      2.0   108.0    1.0      1.5
# 2   67  0.0  3.0     120.0  229.0  0.0      2.0   129.0    1.0      2.6
# 3   37  0.0  2.0     130.0  250.0  0.0      0.0   187.0    0.0      3.5
# 4   41  1.0  1.0     130.0  204.0  0.0      2.0   172.0    0.0      1.4
#
#    slope   ca  thal  heart_status
# 0    2.0  0.0     1           0.0
# 1    1.0  3.0     0           2.0
# 2    1.0  2.0     2           1.0
# 3    2.0  0.0     0           0.0
# 4    0.0  0.0     0           0.0

# %%
# Getting rid of rows with empty cells
heart_data = heart_data.fillna(0)
heart_data.size
heart_data.shape
# Out:
# (919, 14)

# %%
# Data preprocessing according to dataset description
# Encode categorical variables and standardize numeric features
# Mapping categorical columns to ensure all are numeric
heart_data.loc[:, 'sex'] = heart_data['sex'].astype(int)
heart_data.loc[:, 'cp'] = heart_data['cp'].astype(int)
heart_data.loc[:, 'fbs'] = heart_data['fbs'].astype(int)
heart_data.loc[:, 'restecg'] = heart_data['restecg'].astype(int)
heart_data.loc[:, 'exang'] = heart_data['exang'].astype(int)
heart_data.loc[:, 'slope'] = heart_data['slope'].astype(int)
heart_data.loc[:, 'thal'] = heart_data['thal'].astype(int)

# Defining features and labels
X = heart_data.drop(columns = 'heart_status', axis=1).values  # Features
y = heart_data['heart_status']  # Target

# Train-test split with stratification
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (919, 13) (735, 13) (184, 13)

# %%
# Defining the neural network for multi-class classification
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(5, activation='softmax'))  # 5 output nodes for classes 0-4

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 106ms/step - accuracy: 0.1746 - loss: 1.6068 - val_accuracy: 0.2245 - val_loss: 1.5618
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2699 - loss: 1.5604 - val_accuracy: 0.3673 - val_loss: 1.5168
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3736 - loss: 1.4951 - val_accuracy: 0.4218 - val_loss: 1.4706
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4518 - loss: 1.4356 - val_accuracy: 0.4422 - val_loss: 1.4281
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4391 - loss: 1.3970 - val_accuracy: 0.4490 - val_loss: 1.3892
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4074 - loss: 1.3849 - val_accuracy: 0.4354 - val_loss: 1.3545
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4993 - loss: 1.2970 - val_accuracy: 0.4558 - val_loss: 1.3228
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5317 - loss: 1.2393 - val_accuracy: 0.4694 - val_loss: 1.2942
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5292 - loss: 1.1977 - val_accuracy: 0.4694 - val_loss: 1.2684
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5215 - loss: 1.2066 - val_accuracy: 0.4694 - val_loss: 1.2461
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5303 - loss: 1.1907 - val_accuracy: 0.4830 - val_loss: 1.2253
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5440 - loss: 1.1392 - val_accuracy: 0.4966 - val_loss: 1.2071
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5392 - loss: 1.1446 - val_accuracy: 0.4830 - val_loss: 1.1891
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5804 - loss: 1.0573 - val_accuracy: 0.4898 - val_loss: 1.1715
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5759 - loss: 1.0793 - val_accuracy: 0.4898 - val_loss: 1.1570
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6039 - loss: 1.0279 - val_accuracy: 0.4966 - val_loss: 1.1418
# Epoch 17/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6075 - loss: 0.9919 - val_accuracy: 0.4966 - val_loss: 1.1285
# Epoch 18/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5702 - loss: 1.0643 - val_accuracy: 0.5034 - val_loss: 1.1176
# Epoch 19/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5736 - loss: 0.9931 - val_accuracy: 0.5238 - val_loss: 1.1054
# Epoch 20/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5795 - loss: 1.0179 - val_accuracy: 0.5102 - val_loss: 1.0965
# Epoch 21/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6108 - loss: 0.9658 - val_accuracy: 0.5306 - val_loss: 1.0862
# Epoch 22/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5984 - loss: 0.9623 - val_accuracy: 0.5306 - val_loss: 1.0792
# Epoch 23/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6173 - loss: 0.9492 - val_accuracy: 0.5306 - val_loss: 1.0697
# Epoch 24/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6114 - loss: 0.9444 - val_accuracy: 0.5374 - val_loss: 1.0631
# Epoch 25/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6484 - loss: 0.9028 - val_accuracy: 0.5374 - val_loss: 1.0565
# Epoch 26/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6265 - loss: 0.9113 - val_accuracy: 0.5442 - val_loss: 1.0520
# Epoch 27/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6316 - loss: 0.9277 - val_accuracy: 0.5442 - val_loss: 1.0439
# Epoch 28/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6499 - loss: 0.8895 - val_accuracy: 0.5510 - val_loss: 1.0405
# Epoch 29/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6616 - loss: 0.8671 - val_accuracy: 0.5578 - val_loss: 1.0350
# Epoch 30/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6375 - loss: 0.8813 - val_accuracy: 0.5646 - val_loss: 1.0288
# Epoch 31/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6404 - loss: 0.9048 - val_accuracy: 0.5646 - val_loss: 1.0265
# Epoch 32/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6450 - loss: 0.8930 - val_accuracy: 0.5646 - val_loss: 1.0224
# Epoch 33/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6549 - loss: 0.8685 - val_accuracy: 0.5646 - val_loss: 1.0189
# Epoch 34/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6646 - loss: 0.8396 - val_accuracy: 0.5578 - val_loss: 1.0167
# Epoch 35/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6313 - loss: 0.8819 - val_accuracy: 0.5714 - val_loss: 1.0127
# Epoch 36/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6658 - loss: 0.8989 - val_accuracy: 0.5714 - val_loss: 1.0102
# Epoch 37/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6801 - loss: 0.8477 - val_accuracy: 0.5714 - val_loss: 1.0068
# Epoch 38/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6506 - loss: 0.8896 - val_accuracy: 0.5714 - val_loss: 1.0032
# Epoch 39/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6562 - loss: 0.8260 - val_accuracy: 0.5714 - val_loss: 1.0019
# Epoch 40/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6848 - loss: 0.8184 - val_accuracy: 0.5714 - val_loss: 1.0001
# Epoch 41/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6691 - loss: 0.8532 - val_accuracy: 0.5714 - val_loss: 0.9988
# Epoch 42/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6729 - loss: 0.8195 - val_accuracy: 0.5782 - val_loss: 0.9970
# Epoch 43/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6802 - loss: 0.8369 - val_accuracy: 0.5918 - val_loss: 0.9943
# Epoch 44/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6573 - loss: 0.8242 - val_accuracy: 0.5850 - val_loss: 0.9940
# Epoch 45/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6785 - loss: 0.7940 - val_accuracy: 0.5986 - val_loss: 0.9918
# Epoch 46/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6572 - loss: 0.8423 - val_accuracy: 0.5986 - val_loss: 0.9887
# Epoch 47/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6534 - loss: 0.8568 - val_accuracy: 0.5986 - val_loss: 0.9888
# Epoch 48/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6595 - loss: 0.8246 - val_accuracy: 0.5986 - val_loss: 0.9880
# Epoch 49/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6604 - loss: 0.8154 - val_accuracy: 0.5918 - val_loss: 0.9859
# Epoch 50/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6602 - loss: 0.8261 - val_accuracy: 0.5918 - val_loss: 0.9841
# Epoch 51/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6440 - loss: 0.8454 - val_accuracy: 0.5986 - val_loss: 0.9819
# Epoch 52/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6765 - loss: 0.7946 - val_accuracy: 0.5918 - val_loss: 0.9812
# Epoch 53/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6576 - loss: 0.8483 - val_accuracy: 0.5918 - val_loss: 0.9804
# Epoch 54/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6796 - loss: 0.7549 - val_accuracy: 0.5986 - val_loss: 0.9802
# Epoch 55/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6728 - loss: 0.8055 - val_accuracy: 0.5986 - val_loss: 0.9791
# Epoch 56/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6752 - loss: 0.8269 - val_accuracy: 0.5986 - val_loss: 0.9763
# Epoch 57/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6976 - loss: 0.7584 - val_accuracy: 0.6054 - val_loss: 0.9760
# Epoch 58/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6729 - loss: 0.8284 - val_accuracy: 0.6054 - val_loss: 0.9745
# Epoch 59/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7066 - loss: 0.7560 - val_accuracy: 0.6122 - val_loss: 0.9727
# Epoch 60/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6788 - loss: 0.7636 - val_accuracy: 0.6054 - val_loss: 0.9713
# Epoch 61/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6996 - loss: 0.7845 - val_accuracy: 0.6054 - val_loss: 0.9714
# Epoch 62/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7040 - loss: 0.7422 - val_accuracy: 0.6054 - val_loss: 0.9715
# Epoch 63/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7180 - loss: 0.7364 - val_accuracy: 0.6054 - val_loss: 0.9710
# Epoch 64/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6725 - loss: 0.8078 - val_accuracy: 0.6054 - val_loss: 0.9702
# Epoch 65/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6652 - loss: 0.7759 - val_accuracy: 0.6054 - val_loss: 0.9703
# Epoch 66/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6997 - loss: 0.7812 - val_accuracy: 0.6054 - val_loss: 0.9673
# Epoch 67/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7003 - loss: 0.7589 - val_accuracy: 0.6054 - val_loss: 0.9676
# Epoch 68/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7125 - loss: 0.7282 - val_accuracy: 0.6122 - val_loss: 0.9665
# Epoch 69/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6874 - loss: 0.7664 - val_accuracy: 0.6122 - val_loss: 0.9654
# Epoch 70/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6691 - loss: 0.7704 - val_accuracy: 0.6122 - val_loss: 0.9658
# Epoch 71/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7151 - loss: 0.7559 - val_accuracy: 0.6122 - val_loss: 0.9648
# Epoch 72/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7149 - loss: 0.7393 - val_accuracy: 0.6122 - val_loss: 0.9659
# Epoch 73/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7117 - loss: 0.7889 - val_accuracy: 0.6122 - val_loss: 0.9622
# Epoch 74/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6917 - loss: 0.7834 - val_accuracy: 0.6190 - val_loss: 0.9636
# Epoch 75/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6995 - loss: 0.7562 - val_accuracy: 0.6190 - val_loss: 0.9635
# Epoch 76/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7009 - loss: 0.7655 - val_accuracy: 0.6122 - val_loss: 0.9628
# Epoch 77/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6997 - loss: 0.7569 - val_accuracy: 0.6190 - val_loss: 0.9635
# Epoch 78/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6847 - loss: 0.7740 - val_accuracy: 0.6190 - val_loss: 0.9605
# Epoch 79/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6745 - loss: 0.8195 - val_accuracy: 0.6122 - val_loss: 0.9588
# Epoch 80/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7024 - loss: 0.7606 - val_accuracy: 0.6190 - val_loss: 0.9624
# Epoch 81/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7152 - loss: 0.7456 - val_accuracy: 0.6122 - val_loss: 0.9601
# Epoch 82/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7417 - loss: 0.7039 - val_accuracy: 0.6190 - val_loss: 0.9583
# Epoch 83/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7094 - loss: 0.7555 - val_accuracy: 0.6190 - val_loss: 0.9595
# Epoch 84/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7183 - loss: 0.7325 - val_accuracy: 0.6122 - val_loss: 0.9575
# Epoch 85/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7244 - loss: 0.7175 - val_accuracy: 0.6122 - val_loss: 0.9579
# Epoch 86/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6968 - loss: 0.7741 - val_accuracy: 0.6054 - val_loss: 0.9579
# Epoch 87/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7200 - loss: 0.6965 - val_accuracy: 0.6054 - val_loss: 0.9579
# Epoch 88/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7251 - loss: 0.7111 - val_accuracy: 0.6054 - val_loss: 0.9560
# Epoch 89/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7317 - loss: 0.7102 - val_accuracy: 0.6122 - val_loss: 0.9545
# Epoch 90/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6907 - loss: 0.7660 - val_accuracy: 0.6054 - val_loss: 0.9562
# Epoch 91/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7544 - loss: 0.7066 - val_accuracy: 0.6054 - val_loss: 0.9559
# Epoch 92/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7192 - loss: 0.7394 - val_accuracy: 0.6054 - val_loss: 0.9555
# Epoch 93/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7178 - loss: 0.7115 - val_accuracy: 0.6054 - val_loss: 0.9565
# Epoch 94/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7220 - loss: 0.7255 - val_accuracy: 0.6054 - val_loss: 0.9528
# Epoch 95/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6970 - loss: 0.7396 - val_accuracy: 0.6054 - val_loss: 0.9540
# Epoch 96/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6874 - loss: 0.7567 - val_accuracy: 0.6054 - val_loss: 0.9551
# Epoch 97/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7467 - loss: 0.6783 - val_accuracy: 0.6054 - val_loss: 0.9555
# Epoch 98/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6983 - loss: 0.7544 - val_accuracy: 0.6054 - val_loss: 0.9550
# Epoch 99/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7417 - loss: 0.6660 - val_accuracy: 0.6054 - val_loss: 0.9527
# Epoch 100/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7073 - loss: 0.7506 - val_accuracy: 0.6190 - val_loss: 0.9557

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.6813 - loss: 0.9387
# Test Loss: 0.9245287179946899, Test Accuracy: 0.6630434989929199

# %%
# Define the new patient data
new_patients = {
    "Patient CL": [64, 1, 3, 110, 211, 0, 0, 144, 1, 1.8, 1, 0, 2],
    "Patient CK": [63, 1, 3, 140, 463, 0, 2, 104, 0, 4, 1, 3, 2],
    "Patient CT": [54, 1, 0, 98, 306, 1, 0, 128, 1, 0, 1, 1, 0],
    "Patient CJ": [39, 0, 1, 120, 260, 0, 1, 202, 0, 0.9, 2, 0, 2],
    "Patient CD": [77, 1, 1, 356, 145, 0, 1, 143, 0, 0, 1, 0, 2],
    "Patient CZ": [45, 0, 3, 102, 333, 0, 2, 117, 1, 0, 1, 3, 1],
    "Patient CA": [22, 1, 3, 108, 194, 1, 0, 136, 0, 1.9, 1, 3, 0],
    "Patient CF": [51, 0, 2, 190, 0, 0, 0, 92, 0, 2.4, 1, 2, 0],
    "Patient CV": [48, 0, 2, 140, 141.15, 0, 1, 93.34, 1, 1.5, 1, 3, 2],
    "Patient CM": [56, 0, 1, 135.82, 142, 1, 0, 226.17, 1, 2.545, 1, 2, 2]
}

# Convert to DataFrame
new_patients_df = pd.DataFrame(new_patients).T
new_patients_df.columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
                           'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal']

# Preprocess the new patient data
new_patients_scaled = scaler.transform(new_patients_df)

# Predict heart disease status
predictions = model.predict(new_patients_scaled)
predicted_classes = np.argmax(predictions, axis=1)

# Display predictions
for patient, prediction in zip(new_patients.keys(), predicted_classes):
    print(f"{patient}: Predicted Heart Disease Status = {prediction}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# WARNING:tensorflow:6 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c880a9cc3a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Patient CL: Predicted Heart Disease Status = 1
# Patient CK: Predicted Heart Disease Status = 3
# Patient CT: Predicted Heart Disease Status = 0
# Patient CJ: Predicted Heart Disease Status = 1
# Patient CD: Predicted Heart Disease Status = 1
# Patient CZ: Predicted Heart Disease Status = 3
# Patient CA: Predicted Heart Disease Status = 3
# Patient CF: Predicted Heart Disease Status = 2
# Patient CV: Predicted Heart Disease Status = 3
# Patient CM: Predicted Heart Disease Status = 3
